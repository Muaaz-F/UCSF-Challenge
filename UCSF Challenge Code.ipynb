# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
datafile = np.load('chestmnist.npz')

# %%
list(datafile.keys())
# Out:
# ['train_images',
#  'val_images',
#  'test_images',
#  'train_labels',
#  'val_labels',
#  'test_labels']

# %%
image = datafile['train_images'][0]
plt.imshow(image, cmap='gray')
plt.title('Muaaz_Faiyazuddin_1')
plt.axis('on')
plt.grid(None)
plt.show()

# %%
image = np.invert(datafile['train_images'][0])
plt.imshow(image, cmap='gray')
plt.title('Muaaz_Faiyazuddin_2')
plt.axis('on')
plt.grid(None)
plt.show()

# %%
NoiseFree_fourier_gaussian = ndimage.fourier_gaussian(datafile['train_images'][0], sigma=0.05)

x_prewitt = ndimage.prewitt(NoiseFree_fourier_gaussian, axis=0)
y_prewitt = ndimage.prewitt(NoiseFree_fourier_gaussian, axis=1)

image_canny = np.hypot(x_prewitt, y_prewitt)
image_canny *= 255.0 / np.max(xray_image_canny)

plt.imshow(image_canny, cmap = "plasma")
plt.title('Muaaz_Faiyazuddin_3')
plt.axis('on')
plt.grid(None)
plt.show()

# %% [markdown]
# Edge detection using CannyFIlter Technique and edges emphasized using plasma colormap of matplotlib

# %% [markdown]
# Citations:
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.gaussian_filter.html
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
